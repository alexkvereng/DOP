# %%
# !g++ logman1.cpp -o logman

# %%
# !./logman -r 3 data.in.txt
# Out:
# 3

# %%
# !./logman -r 566 data.in.txt
# Out:
# 0

# %%
# !./logman -r 7 data.in.txt
# Out:
# 7

# %%
# !./logman -w 1 data.in.txt
# Out:
# 0

# %%
# !./logman -w 123 data.in.txt
# Out:
# 8

# %%
# !./logman -w 35 data.in.txt
# Out:
# 9

# %%
# !./logman -w 14 data.in.txt
# Out:
# 11

# %%
# !./logman -w 56 data.in.txt
# Out:
# 12

# %%
# !./logman -w 56900 data.in.txt
# Out:
# 0
